# %%
##Task Upon the Global Super Store

# %%
import pyodbc

# %%
import pyodbc
connection_string = "Driver=SQL Server;Server=localhost\MSSQLSERVER2017;Database={SQL_Learnings};Trusted_Connection=Yes;"

# %%
import pandas as pd
import os
df = pd.read_csv(r"C:\Users\charap\Downloads\Global Superstore-1.csv")
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891   7/31/2012   7/31/2012      Same Day    RH-19495
# 1   26341    IN-2013-77878    2/5/2013    2/7/2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  10/17/2013  10/18/2013   First Class    CR-12730
# 3   13524  ES-2013-1579342   1/28/2013   1/30/2013   First Class    KM-16375
# 4   47221     SG-2013-4320   11/5/2013   11/6/2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  \
# 0       Rick Hansen     Consumer  New York City         New York
# 1     Justin Ritter    Corporate     Wollongong  New South Wales
# 2      Craig Reiter     Consumer       Brisbane       Queensland
# 3  Katherine Murray  Home Office         Berlin           Berlin
# 4       Rick Hansen     Consumer          Dakar            Dakar
#
#         ...              Product ID    Category Sub-Category  \
# ...

# %%
import pandas as pd
from sqlalchemy import Table, MetaData, create_engine
metadata=MetaData()
engine=create_engine('sqlite:///Global Superstore-1.db')
#df.to_sql('orders',engine)
orders = Table('orders',metadata, autoload = True, autoload_with = engine)

# %%
print(engine.table_names())
# Out:
# ['orders']

# %%
from sqlalchemy import select
connection = engine.connect()
stmt = select([orders.columns.City])
results = connection.execute(stmt).fetchall()
print(results)
# Out:
# [('New York City',), ('Wollongong',), ('Brisbane',), ('Berlin',), ('Dakar',), ('Sydney',), ('Porirua',), ('Hamilton',), ('Sacramento',), ('Concord',), ('Alexandria',), ('Kabul',), ('Jizan',), ('Toledo',), ('Mudanjiang',), ('Paris',), ('Henderson',), ('Prato',), ('Townsville',), ('Uvinza',), ('Bytom',), ('Chicago',), ('Suzhou',), ('Edinburgh',), ('Juárez',), ('Soyapango',), ('Taipei',), ('Leipzig',), ('Los Angeles',), ('Surat',), ('Santo Domingo',), ('Saint-Brieuc',), ('Amarillo',), ('Gold Coast',), ('Fresno',), ('Kamina',), ('New York City',), ('Burlington',), ('Stockton-on-Tees',), ('Brisbane',), ('Mataram',), ('Gorakhpur',), ('Thiruvananthapuram',), ('Huddersfield',), ('Berlin',), ('Minneapolis',), ('Montreuil',), ('Shouguang',), ('Jamshedpur',), ('Paysandú',), ('New York City',), ('Behshahr',), ('Huntington Beach',), ('Taipei',), ('Maputo',), ('Bhopal',), ('Seattle',), ('Delhi',), ('Geraldton',), ('Tallahassee',), ('Dhaka',), ('New York City',), ('Munster',), ('Celle',), ('Wuxi',)
# ...

# %%
from sqlalchemy import select
connection = engine.connect()
stmt = select([orders])
results = connection.execute(stmt).fetchmany(5)
print(results)
# Out:
# [(0, 32298, 'CA-2012-124891', '7/31/2012', '7/31/2012', 'Same Day', 'RH-19495', 'Rick Hansen', 'Consumer', 'New York City', 'New York', 'United States', 10024.0, 'US', 'East', 'TEC-AC-10003033', 'Technology', 'Accessories', 'Plantronics CS510 - Over-the-Head monaural Wireless Headset System', 2309.65, 7, 0.0, 762.1845, 933.57, 'Critical'), (1, 26341, 'IN-2013-77878', '2/5/2013', '2/7/2013', 'Second Class', 'JR-16210', 'Justin Ritter', 'Corporate', 'Wollongong', 'New South Wales', 'Australia', None, 'APAC', 'Oceania', 'FUR-CH-10003950', 'Furniture', 'Chairs', 'Novimex Executive Leather Armchair, Black', 3709.395, 9, 0.1, -288.765, 923.63, 'Critical'), (2, 25330, 'IN-2013-71249', '10/17/2013', '10/18/2013', 'First Class', 'CR-12730', 'Craig Reiter', 'Consumer', 'Brisbane', 'Queensland', 'Australia', None, 'APAC', 'Oceania', 'TEC-PH-10004664', 'Technology', 'Phones', 'Nokia Smart Phone, with Caller ID', 5175.170999999999, 9, 0.1, 919.971, 915.49, 'Medium'), (3, 13524, 'ES-2013-1579342',
# ...

# %%
import pandas as pd 
df = pd.DataFrame(results)
df.columns = results[0].keys()
print(df)
# Out:
#    index  Row ID         Order ID  Order Date   Ship Date     Ship Mode  \
# 0      0   32298   CA-2012-124891   7/31/2012   7/31/2012      Same Day
# 1      1   26341    IN-2013-77878    2/5/2013    2/7/2013  Second Class
# 2      2   25330    IN-2013-71249  10/17/2013  10/18/2013   First Class
# 3      3   13524  ES-2013-1579342   1/28/2013   1/30/2013   First Class
# 4      4   47221     SG-2013-4320   11/5/2013   11/6/2013      Same Day
#
#   Customer ID     Customer Name      Segment           City       ...        \
# 0    RH-19495       Rick Hansen     Consumer  New York City       ...
# 1    JR-16210     Justin Ritter    Corporate     Wollongong       ...
# 2    CR-12730      Craig Reiter     Consumer       Brisbane       ...
# 3    KM-16375  Katherine Murray  Home Office         Berlin       ...
# 4     RH-9495       Rick Hansen     Consumer          Dakar       ...
#
#          Product ID    Category  Sub-Category  \
# 0   TEC-AC-10003033  Technology   Accessories
# ...

# %%
df = df.append({'Row ID':80000,
'Order ID':'CA-2012-124891',
'Order Date':'7/31/2012',
'Ship Date':'7/31/2012',
'Ship Mode':'Same Day',
'Customer ID':'RH-3478',
'Customer Name':'Charan Tej',
'Segment':'Consumer',
'City':'New York City',
'State':'Karnataka',
'Product ID':'TEC-AC-10003033',
'Category':'Technology',
'Sub-Category':'Accessories',
'Product Name':'Nokia Smart Phone, with Caller ID',
'Sales':4000,
'Quantity':8,
'Discount':0.3,
'Profit':700,
'Shipping Cost':600,
'Order Priority':'Medium'},ignore_index=True)

# %%
df = df.iloc[[0,-1]]
print(df)
# Out:
#    index  Row ID        Order ID Order Date  Ship Date Ship Mode Customer ID  \
# 0    0.0   32298  CA-2012-124891  7/31/2012  7/31/2012  Same Day    RH-19495
# 5    NaN   80000  CA-2012-124891  7/31/2012  7/31/2012  Same Day     RH-3478
#
#   Customer Name   Segment           City       ...             Product ID  \
# 0   Rick Hansen  Consumer  New York City       ...        TEC-AC-10003033
# 5    Charan Tej  Consumer  New York City       ...        TEC-AC-10003033
#
#      Category  Sub-Category  \
# 0  Technology   Accessories
# 5  Technology   Accessories
#
#                                         Product Name    Sales Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.65        7
# 5                  Nokia Smart Phone, with Caller ID  4000.00        8
#
#   Discount    Profit Shipping Cost  Order Priority
# 0      0.0  762.1845        933.57        Critical
# 5      0.3  700.0000        600.00          Medium
#
# [2 rows x 25 columns]

# %%
List1 = [80001,   'CA-2012-124891',   '7/31/2012',   '7/31/2012',      'Same Day',  'RH-19495',       'Chandan' ,    'Consumer' , 'New York City','New South Wales', 'TEC-AC-10003033',  'Technology',   'Accessories','Motorola Smart Phone, Cordless', 5000, 7, 0.3, 488, 800, 'Critical' ]
print(List1)
# Out:
# [80001, 'CA-2012-124891', '7/31/2012', '7/31/2012', 'Same Day', 'RH-19495', 'Chandan', 'Consumer', 'New York City', 'New South Wales', 'TEC-AC-10003033', 'Technology', 'Accessories', 'Motorola Smart Phone, Cordless', 5000, 7, 0.3, 488, 800, 'Critical']

# %%
from sqlalchemy import insert
stmt = insert(orders)
values_list = [{'Row ID':80000,
'Order ID':'CA-2012-124891',
'Order Date':'7/31/2012',
'Ship Date':'7/31/2012',
'Ship Mode':'Same Day',
'Customer ID':'RH-3478',
'Customer Name':'Charan Tej',
'Segment':'Consumer',
'City':'New York City',
'State':'Karnataka',
'Product ID':'TEC-AC-10003033',
'Category':'Technology',
'Sub-Category':'Accessories',
'Product Name':'Nokia Smart Phone, with Caller ID',
'Sales':4000,
'Quantity':8,
'Discount':0.3,
'Profit':700,
'Shipping Cost':600,
'Order Priority':'Medium'},
{'Row ID':80001,
'Order ID':'CA-2012-124891',
'Order Date':'7/31/2015',
'Ship Date':'7/31/2015',
'Ship Mode':'Same Day',
'Customer ID':'RH-3478',
'Customer Name':'Chandan',
'Segment':'Consumer',
'City':'New York City',
'State':'Karnataka',
'Product ID':'TEC-AC-10003033',
'Category':'Technology',
'Sub-Category':'Accessories',
'Product Name':'Nokia Smart Phone, with Caller ID',
'Sales':3000,
'Quantity':8,
'Discount':0.5,
'Profit':700,
'Shipping Cost':800,
'Order Priority':'Critical'},
{'Row ID':80002,
'Order ID':'CA-2012-124891',
'Order Date':'7/31/2016',
'Ship Date':'7/31/2016',
'Ship Mode':'Standard',
'Customer ID':'RH-3478',
'Customer Name':'Sneha',
'Segment':'Consumer',
'City':'New York City',
'State':'Karnataka',
'Product ID':'TEC-AC-10003033',
'Category':'Technology',
'Sub-Category':'Accessories',
'Product Name':'Nokia Smart Phone, with Caller ID',
'Sales':6000,
'Quantity':5,
'Discount':0.6,
'Profit':700,
'Shipping Cost':567,
'Order Priority':'Medium'},
{'Row ID':80003,
'Order ID':'CA-2012-124891',
'Order Date':'7/31/2012',
'Ship Date':'7/31/2012',
'Ship Mode':'Same Day',
'Customer ID':'RH-3478',
'Customer Name':'Maruthi',
'Segment':'Consumer',
'City':'New York City',
'State':'Karnataka',
'Product ID':'TEC-AC-10003033',
'Category':'Technology',
'Sub-Category':'Accessories',
'Product Name':'Nokia Smart Phone, with Caller ID',
'Sales':5000,
'Quantity':4,
'Discount':0.4,
'Profit':756,
'Shipping Cost':687,
'Order Priority':'Critical'},
{'Row ID':80004,
'Order ID':'CA-2012-124891',
'Order Date':'7/31/2012',
'Ship Date':'7/31/2012',
'Ship Mode':'Same Day',
'Customer ID':'RH-3478',
'Customer Name':'Ankit',
'Segment':'Consumer',
'City':'New York City',
'State':'Karnataka',
'Product ID':'TEC-AC-10003033',
'Category':'Technology',
'Sub-Category':'Accessories',
'Product Name':'Nokia Smart Phone, with Caller ID',
'Sales':9000,
'Quantity':12,
'Discount':0.1,
'Profit':398,
'Shipping Cost':800,
'Order Priority':'Medium'},
{'Row ID':80005,
'Order ID':'CA-2012-124891',
'Order Date':'7/31/2012',
'Ship Date':'7/31/2012',
'Ship Mode':'Same Day',
'Customer ID':'RH-3478',
'Customer Name':'Avinash',
'Segment':'Consumer',
'City':'New York City',
'State':'Karnataka',
'Product ID':'TEC-AC-10003033',
'Category':'Technology',
'Sub-Category':'Accessories',
'Product Name':'Nokia Smart Phone, with Caller ID',
'Sales':7000,
'Quantity':13,
'Discount':0.2,
'Profit':400,
'Shipping Cost':600,
'Order Priority':'Medium'}
              ]
result_proxy = connection.execute(stmt, values_list)
print(result_proxy.rowcount)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\sql\selectable.py in _interpret_as_from(element)
#      46     try:
# ---> 47         return insp.selectable
#      48     except AttributeError:
#
# AttributeError: 'NoneType' object has no attribute 'selectable'
#
# During handling of the above exception, another exception occurred:
#
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-28-d736c3e7e632> in <module>
#       1 from sqlalchemy import insert
# ----> 2 stmt = insert(orders)
#       3 values_list = [{'Row ID':80000,
#       4 'Order ID':'CA-2012-124891',
#       5 'Order Date':'7/31/2012',
#
# <string> in insert(table, values, inline, bind, prefixes, returning, return_defaults, **dialect_kw)
#
# ...

# %%
stmt = 'select * from orders'
for i in range (-1,-6,-1):
    orders = connection.execute(stmt).fetchall()[i]  
    print(orders)
# Out:
# (None, 80005, 'CA-2012-124891', '7/31/2012', '7/31/2012', 'Same Day', 'RH-3478', 'Avinash', 'Consumer', 'New York City', 'Karnataka', None, None, None, None, 'TEC-AC-10003033', 'Technology', 'Accessories', 'Nokia Smart Phone, with Caller ID', 7000.0, 13, 0.2, 400.0, 600.0, 'Medium')
# (None, 80004, 'CA-2012-124891', '7/31/2012', '7/31/2012', 'Same Day', 'RH-3478', 'Ankit', 'Consumer', 'New York City', 'Karnataka', None, None, None, None, 'TEC-AC-10003033', 'Technology', 'Accessories', 'Nokia Smart Phone, with Caller ID', 9000.0, 12, 0.1, 398.0, 800.0, 'Medium')
# (None, 80003, 'CA-2012-124891', '7/31/2012', '7/31/2012', 'Same Day', 'RH-3478', 'Maruthi', 'Consumer', 'New York City', 'Karnataka', None, None, None, None, 'TEC-AC-10003033', 'Technology', 'Accessories', 'Nokia Smart Phone, with Caller ID', 5000.0, 4, 0.4, 756.0, 687.0, 'Critical')
# ...

# %%
from sqlalchemy import update
stmt = update(orders)
stmt = stmt.where(orders.columns.Sales == True)
stmt = stmt.values(City = 'Goa', Quantity = 30 )
result_proxy = connection.execute(stmt)
print(result_proxy.rowcount)

# %%
stmt = connection.execute("UPDATE orders SET City = 'Bangalore' WHERE Segment = 'Consumer' ")
stmt = 'select * from orders'
for i in range (-1,-6,-1):
    orders = connection.execute(stmt).fetchall()[i]  
    print(orders)
# Out:
# (None, 80005, 'CA-2012-124891', '7/31/2012', '7/31/2012', 'Same Day', 'RH-3478', 'Avinash', 'Consumer', 'Bangalore', 'Karnataka', None, None, None, None, 'TEC-AC-10003033', 'Technology', 'Accessories', 'Nokia Smart Phone, with Caller ID', 7000.0, 13, 0.2, 400.0, 600.0, 'Medium')
# (None, 80004, 'CA-2012-124891', '7/31/2012', '7/31/2012', 'Same Day', 'RH-3478', 'Ankit', 'Consumer', 'Bangalore', 'Karnataka', None, None, None, None, 'TEC-AC-10003033', 'Technology', 'Accessories', 'Nokia Smart Phone, with Caller ID', 9000.0, 12, 0.1, 398.0, 800.0, 'Medium')
# (None, 80003, 'CA-2012-124891', '7/31/2012', '7/31/2012', 'Same Day', 'RH-3478', 'Maruthi', 'Consumer', 'Bangalore', 'Karnataka', None, None, None, None, 'TEC-AC-10003033', 'Technology', 'Accessories', 'Nokia Smart Phone, with Caller ID', 5000.0, 4, 0.4, 756.0, 687.0, 'Critical')
# ...

# %%
stmt = connection.execute("DELETE from orders where City = 'Bangalore'")
stmt = 'select * from orders'
for i in range (-1,-6,-1):
    orders = connection.execute(stmt).fetchall()[i]  
    print(orders)
# Out:
# (51288, 9596, 'MX-2012-140767', '2/18/2012', '2/22/2012', 'Standard Class', 'RB-19795', 'Ross Baird', 'Home Office', 'Valinhos', 'São Paulo', 'Brazil', None, 'LATAM', 'South', 'OFF-BI-10000806', 'Office Supplies', 'Binders', 'Acco Index Tab, Economy', 13.44, 2, 0.0, 2.4, 0.0, 'Medium')
# (51287, 40470, 'US-2013-155768', '12/2/2013', '12/2/2013', 'Same Day', 'LB-16795', 'Laurel Beltran', 'Home Office', 'Oxnard', 'California', 'United States', 93030.0, 'US', 'West', 'OFF-EN-10001219', 'Office Supplies', 'Envelopes', '#10- 4 1/8" x 9 1/2" Security-Tint Envelopes', 22.92, 3, 0.0, 11.2308, 0.01, 'High')
# (51285, 29002, 'IN-2014-62366', '6/19/2014', '6/19/2014', 'Same Day', 'KE-16420', 'Katrina Edelman', 'Corporate', 'Kure', 'Hiroshima', 'Japan', None, 'APAC', 'North Asia', 'OFF-FA-10000746', 'Office Supplies', 'Fasteners', 'Advantus Thumb Tacks, 12 Pack', 65.1, 5, 0.0, 4.5, 0.01, 'Medium')
# ...

# %% [raw]
# from sqlalchemy import func
# stmt = select([func.sum(orders.columns.)])
# results = connection.execute(stmt).scalar()
# print(results)

# %%
stmt = 'select sum(Sales) from orders'
results = connection.execute(stmt).scalar()
print(results)
# Out:
# 6127004.582020108

# %%
stmt = 'select MAX(Sales) from orders'
results = connection.execute(stmt).scalar()
print(results)
# Out:
# 22638.48

# %%
stmt = 'select MIN(Sales) from orders'
results = connection.execute(stmt).scalar()
print(results)
# Out:
# 0.556

# %%
stmt = 'select count(*) from orders'
results = connection.execute(stmt).scalar()
print(results)
# Out:
# 24740

# %%
stmt = 'select count(City) from orders'
results = connection.execute(stmt).scalar()
print(results)
# Out:
# 24740

# %%
import pyodbc
engine = pyodbc.connect("Driver={SQL Server};"
                      "Server=KTCL-5CG9362KK1\SQLEXPRESS;"
                      "Database=Python_Learnings;"
                      "Trusted_Connection=yes;")

cursor = engine.cursor()
stmt = 'SELECT * FROM Orders$'
results = cursor.execute(stmt).fetchall()
first_row = results[0]
print(first_row)
#for row in cursor:
#    print('row = %r' % (row,))
# Out:
# (32298.0, 'CA-2012-124891', datetime.datetime(2012, 7, 31, 0, 0), datetime.datetime(2012, 7, 31, 0, 0), 'Same Day', 'RH-19495', 'Rick Hansen', 'Consumer', 'New York City', 'New York', 'United States', 10024.0, 'US', 'East', 'TEC-AC-10003033', 'Technology', 'Accessories', 'Plantronics CS510 - Over-the-Head monaural Wireless Headset System', 2309.65, 7.0, 0.0, 762.1844999999998, 933.57, 'Critical')

# %%
##Other Method of importing

# %%
import csv
from sqlalchemy import create_engine, Table, MetaData, Integer, Column
engine = create_engine('sqlite:///Python_Learnings.db', echo = True)
metadata = MetaData()
Orders = Table('Orders$', metadata,
              Column('Quantity', Integer),
              Column('Discount', Integer),
              )
metadata.create_all(engine)
insert_qurey = Orders.insert()

with open('')
# Out:
# 2020-03-18 20:17:10,887 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-03-18 20:17:10,888 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-18 20:17:10,889 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-03-18 20:17:10,889 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-18 20:17:10,890 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Orders$")
# 2020-03-18 20:17:10,891 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-18 20:17:10,893 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE "Orders$" (
# 	"Quantity" INTEGER,
# 	"Discount" INTEGER
# )
#
#
# 2020-03-18 20:17:10,894 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-18 20:17:10,906 INFO sqlalchemy.engine.base.Engine COMMIT
